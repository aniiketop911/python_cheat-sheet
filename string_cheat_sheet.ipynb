# %%
name = "Aniket loves Riti"

# %%
print(name.lower())
# Out:
# aniket loves riti

# %%
print(name.upper())
# Out:
# ANIKET LOVES RITI

# %%
print(name.capitalize())
# Out:
# Aniket loves riti

# %%
print(name.title())
# Out:
# Aniket Loves Riti

# %%
print(name.swapcase())#swaps the case of the string
# Out:
# aNIKET LOVES rITI

# %%
print(name.casefold())#changes the case of the string
# Out:
# aniket loves riti

# %%
print(name.find("R"))#first occurence
# Out:
# 13

# %%
print(name.rfind("R"))#last occcurence
# Out:
# 13

# %%
print(name.index('R'))#index value of first occurence
# Out:
# 13

# %%
print(name.rindex("R"))#index value of last occuerence
# Out:
# 13

# %%
print(name.count("i"))
# Out:
# 3

# %%
print(name.startswith("Ri"))
# Out:
# False

# %%
print(name.startswith("An"))#boolean case if the string starts with give substring
# Out:
# True

# %%
print(name.endswith("ti"))#boolean case if the string ends with the given substring
# Out:
# True

# %%
print(name.isalnum())#boolean for string is alphanumeric
# Out:
# False

# %%
print(name.isalpha())#all character is alphabet
# Out:
# False

# %%
print(name.isdigit())#all character is digit
# Out:
# False

# %%
print(name.isnumeric())
# Out:
# False

# %%
print(name.islower())
# Out:
# False

# %%
print(name.isupper())
# Out:
# False

# %%
print(name.istitle())
# Out:
# False

# %%
print(name.isspace())
# Out:
# False

# %%
print(name.isidentifier())#method in Python checks whether a string is a valid identifier. An identifier is a name given to entities like variables, functions, classes, etc. A string is considered a valid identifier if it only contains alphanumeric characters (a-z, A-Z, 0-9) or underscores (_), and does not start with a number.
# Out:
# False

# %%
print(name.isprintable())#method in Python is a built-in string method used to check if all characters in a string are printable
# Out:
# True

# %%
print(name.isascii())#method checks whether all characters in a string are ASCII characters (code points 0–127).
# Out:
# True
